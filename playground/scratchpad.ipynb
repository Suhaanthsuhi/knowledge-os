# %% [markdown]
# # Scratchpad
#
# Research & Dev Space

# %%
from pathlib import Path
import sys

ROOT_DIR = Path.cwd().parent
sys.path.insert(0, str(ROOT_DIR))

print(ROOT_DIR)
# Out:
# /Users/suhaanthvv/Desktop/projects/ai/knowledge-os

# %%
import os
import sys

print("Python:")
print(sys.executable)

print("\nWorking directory:")
print(os.getcwd())

print("\nPython path:")
for p in sys.path:
    print(p)
# Out:
# Python:
# /Users/suhaanthvv/Desktop/projects/ai/knowledge-os/.venv/bin/python3
#
# Working directory:
# /Users/suhaanthvv/Desktop/projects/ai/knowledge-os/playground
#
# Python path:
# /Users/suhaanthvv/Desktop/projects/ai/knowledge-os
# /Users/suhaanthvv/.local/share/uv/python/cpython-3.13.14-macos-aarch64-none/lib/python313.zip
# /Users/suhaanthvv/.local/share/uv/python/cpython-3.13.14-macos-aarch64-none/lib/python3.13
# /Users/suhaanthvv/.local/share/uv/python/cpython-3.13-macos-aarch64-none/lib/python3.13/lib-dynload
#
# /Users/suhaanthvv/Desktop/projects/ai/knowledge-os/.venv/lib/python3.13/site-packages

# %%
# imports
import os
import sys
from pathlib import Path

from langchain_groq import ChatGroq
from app.config import settings
from app.graph.neo4j import Neo4jClient
from app.extraction.schema import KnowledgeGraph

# %%
extractor = GraphExtractor()

# %%
# neo4j client
neo4j_client = Neo4jClient(
    uri=settings.neo4j_uri,
    username=settings.neo4j_username,
    password=settings.neo4j_password
)

# %%
# test neo4j, open neo4j connection
try:
    neo4j_client.verify_connectivity()
    print("✅ Successfully connected to Neo4j!")

except Exception as e:
    print(f"❌ Error connecting to Neo4j: {e}")
# Out:
# ✅ Successfully connected to Neo4j!

# %%
neo4j_client

# %%
text = """
Apple was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in 1976.
The company is headquartered in Cupertino, California.
Steve Jobs served as the CEO of Apple.
"""
# Out:
# KnowledgeGraph(entities=[Entity(name='Apple', type='Company'), Entity(name='Steve Jobs', type='Person'), Entity(name='Steve Wozniak', type='Person'), Entity(name='Ronald Wayne', type='Person'), Entity(name='Cupertino, California', type='Location'), Entity(name='1976', type='Date')], relationships=[Relationship(source='Apple', relationship='founded_by', target='Steve Jobs'), Relationship(source='Apple', relationship='founded_by', target='Steve Wozniak'), Relationship(source='Apple', relationship='founded_by', target='Ronald Wayne'), Relationship(source='Apple', relationship='founded_in', target='1976'), Relationship(source='Apple', relationship='headquartered_in', target='Cupertino, California'), Relationship(source='Steve Jobs', relationship='CEO_of', target='Apple')])

# %%
# extract
graph = extractor.extract(text)

# %%
# insert 
neo4j.insert_graph(graph)

# %%
# finally close the neo4j connection, after use
neo4j_client.close()

try:
    neo4j_client.verify_connectivity()
    print("✅ Successfully connected to Neo4j!")

except Exception as e:
    print(f"❌ Error connecting to Neo4j: {e}")
# Out:
# ❌ Error connecting to Neo4j: Driver closed
